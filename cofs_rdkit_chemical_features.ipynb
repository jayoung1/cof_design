# %%
import pandas as pd
#import deepchem as dc
from rdkit import rdBase

# %%
from rdkit.Chem import PandasTools, Lipinski, rdqueries
from IPython.display import HTML

# %%
compounds = pd.read_csv("compounds.csv")

# %%
compounds.head()
# Out:
#    Unnamed: 0 linkerA_mol linkerB_mol linkerA_con linkerB_con  \
# 0           0   linker100   linker103         CH2          NH
# 1           1   linker100    linker10         CH2          NH
# 2           2   linker100    linker10         CH2          NH
# 3           3   linker100    linker11         CH2          NH
# 4           4   linker100    linker12         CH2          NH
#
#                        linkerA_smiles  \
# 0  Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O
# 1  Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O
# 2  Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O
# 3  Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O
# 4  Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O
#
#                                       linkerB_smiles  net
# 0  C1=CC=C2C(=C1)C3=CC=CC=C3C24C5=CC(C=CC5=C6C=CC...  pts
# 1           [O-][N+](=O)c1c(Br)ccc(Br)c1[N+]([O-])=O  qtz
# 2           [O-][N+](=O)c1c(Br)ccc(Br)c1[N+]([O-])=O  und
# 3                           Nc1c(N)c(Br)c(N)c(N)c1Br  unc
# 4                           Oc1c(O)c(Br)c(O)c(O)c1Br  qtz

# %%
PandasTools.AddMoleculeColumnToFrame(test,'linkerA_smiles','MoleculeA',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(test,'linkerB_smiles','MoleculeB',includeFingerprints=False)
# Out:
# /usr/local/lib/python3.9/site-packages/rdkit/Chem/PandasTools.py:449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)

# %%
def show_df(df):
    return HTML(df.to_html(notebook=True))

show_df(test)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>linkerA_mol</th>
#       <th>linkerB_mol</th>
#       <th>linkerA_con</th>
#       <th>linkerB_con</th>
#       <th>linkerA_smiles</th>
#       <th>linkerB_smiles</th>
#       <th>net</th>
#       <th>MoleculeA</th>
#       <th>MoleculeB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>linker100</td>
#       <td>linker103</td>
#       <td>CH2</td>
#       <td>NH</td>
#       <td>Oc1c(Br)cc(Br)cc1c2cc(Br)cc(Br)c2O</td>
#       <td>C1=CC=C2C(=C1)C3=CC=CC=C3C24C5=CC(C=CC5=C6C=CC...</td>
#       <td>pts</td>
# ...

# %%
# on the full compounds dataset

# %%
PandasTools.AddMoleculeColumnToFrame(compounds,'linkerA_smiles','MoleculeA',includeFingerprints=False)
PandasTools.AddMoleculeColumnToFrame(compounds,'linkerB_smiles','MoleculeB',includeFingerprints=False)

# %%
q = rdqueries.AtomNumEqualsQueryAtom(6)
compounds['NumC_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(7)
compounds['NumN_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(8)
compounds['NumO_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(9)
compounds['NumF_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(17)
compounds['NumCl_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(35)
compounds['NumBr_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(5)
compounds['NumB_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(14)
compounds['NumSi_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(16)
compounds['NumS_A'] = compounds.apply(lambda x: len(x["MoleculeA"].GetAtomsMatchingQuery(q)), axis=1)

# %%
q = rdqueries.AtomNumEqualsQueryAtom(6)
compounds['NumC_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(7)
compounds['NumN_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(8)
compounds['NumO_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(9)
compounds['NumF_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(17)
compounds['NumCl_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(35)
compounds['NumBr_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(5)
compounds['NumB_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(14)
compounds['NumSi_B'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

q = rdqueries.AtomNumEqualsQueryAtom(16)
compounds['NumS_A'] = compounds.apply(lambda x: len(x["MoleculeB"].GetAtomsMatchingQuery(q)), axis=1)

# %%
compounds['FractionCSP3_A'] = compounds.apply(lambda x: Lipinski.FractionCSP3(x["MoleculeA"]), axis = 1)
#compounds['HeavyAtomCount_A'] = compounds.apply(lambda x: Lipinski.HeavyAtomCount(x["MoleculeA"]), axis = 1)
#compounds['NHOHCount_A'] = compounds.apply(lambda x: Lipinski.NHOHCount(x["MoleculeA"]), axis = 1)
#compounds['NOCount_A'] = compounds.apply(lambda x: Lipinski.NOCount(x["MoleculeA"]), axis = 1)
compounds['NumAliphaticCarbocycles_A'] = compounds.apply(lambda x: Lipinski.NumAliphaticCarbocycles(x["MoleculeA"]), axis = 1)
compounds['NumAliphaticHeterocycles_A'] = compounds.apply(lambda x: Lipinski.NumAliphaticHeterocycles(x["MoleculeA"]), axis = 1)
compounds['NumAliphaticRings_A'] = compounds.apply(lambda x: Lipinski.NumAliphaticRings(x["MoleculeA"]), axis = 1)
compounds['NumAromaticCarbocycles_A'] = compounds.apply(lambda x: Lipinski.NumAromaticCarbocycles(x["MoleculeA"]), axis = 1)
compounds['NumAromaticHeterocycles_A'] = compounds.apply(lambda x: Lipinski.NumAromaticHeterocycles(x["MoleculeA"]), axis = 1)
compounds['NumAromaticRings_A'] = compounds.apply(lambda x: Lipinski.NumAromaticRings(x["MoleculeA"]), axis = 1)
compounds['NumHAcceptors_A'] = compounds.apply(lambda x: Lipinski.NumHAcceptors(x["MoleculeA"]), axis = 1)
compounds['NumHDonors_A'] = compounds.apply(lambda x: Lipinski.NumHDonors(x["MoleculeA"]), axis = 1)
compounds['NumHeteroatoms_A'] = compounds.apply(lambda x: Lipinski.NumHeteroatoms(x["MoleculeA"]), axis = 1)
compounds['NumRotatableBonds_A'] = compounds.apply(lambda x: Lipinski.NumRotatableBonds(x["MoleculeA"]), axis = 1)
compounds['NumSaturatedCarbocycles_A'] = compounds.apply(lambda x: Lipinski.NumSaturatedCarbocycles(x["MoleculeA"]), axis = 1)
compounds['NumSaturatedHeterocycles_A'] = compounds.apply(lambda x: Lipinski.NumSaturatedHeterocycles(x["MoleculeA"]), axis = 1)
compounds['NumSaturatedRings_A'] = compounds.apply(lambda x: Lipinski.NumSaturatedRings(x["MoleculeA"]), axis = 1)
compounds['RingCount_A'] = compounds.apply(lambda x: Lipinski.RingCount(x["MoleculeA"]), axis = 1)

# %%
compounds['FractionCSP3_B'] = compounds.apply(lambda x: Lipinski.FractionCSP3(x["MoleculeB"]), axis = 1)
#compounds['HeavyAtomCount_B'] = compounds.apply(lambda x: Lipinski.HeavyAtomCount(x["MoleculeB"]), axis = 1)
#compounds['NHOHCount_B'] = compounds.apply(lambda x: Lipinski.NHOHCount(x["MoleculeB"]), axis = 1)
#compounds['NOCount_B'] = compounds.apply(lambda x: Lipinski.NOCount(x["MoleculeB"]), axis = 1)
compounds['NumAliphaticCarbocycles_B'] = compounds.apply(lambda x: Lipinski.NumAliphaticCarbocycles(x["MoleculeB"]), axis = 1)
compounds['NumAliphaticHeterocycles_B'] = compounds.apply(lambda x: Lipinski.NumAliphaticHeterocycles(x["MoleculeB"]), axis = 1)
compounds['NumAliphaticRings_B'] = compounds.apply(lambda x: Lipinski.NumAliphaticRings(x["MoleculeB"]), axis = 1)
compounds['NumAromaticCarbocycles_B'] = compounds.apply(lambda x: Lipinski.NumAromaticCarbocycles(x["MoleculeB"]), axis = 1)
compounds['NumAromaticHeterocycles_B'] = compounds.apply(lambda x: Lipinski.NumAromaticHeterocycles(x["MoleculeB"]), axis = 1)
compounds['NumAromaticRings_B'] = compounds.apply(lambda x: Lipinski.NumAromaticRings(x["MoleculeB"]), axis = 1)
compounds['NumHAcceptors_B'] = compounds.apply(lambda x: Lipinski.NumHAcceptors(x["MoleculeB"]), axis = 1)
compounds['NumHDonors_B'] = compounds.apply(lambda x: Lipinski.NumHDonors(x["MoleculeB"]), axis = 1)
compounds['NumHeteroatoms_B'] = compounds.apply(lambda x: Lipinski.NumHeteroatoms(x["MoleculeB"]), axis = 1)
compounds['NumRotatableBonds_B'] = compounds.apply(lambda x: Lipinski.NumRotatableBonds(x["MoleculeB"]), axis = 1)
compounds['NumSaturatedCarbocycles_B'] = compounds.apply(lambda x: Lipinski.NumSaturatedCarbocycles(x["MoleculeB"]), axis = 1)
compounds['NumSaturatedHeterocycles_B'] = compounds.apply(lambda x: Lipinski.NumSaturatedHeterocycles(x["MoleculeB"]), axis = 1)
compounds['NumSaturatedRings_B'] = compounds.apply(lambda x: Lipinski.NumSaturatedRings(x["MoleculeB"]), axis = 1)
compounds['RingCount_B'] = compounds.apply(lambda x: Lipinski.RingCount(x["MoleculeB"]), axis = 1)

# %%
composition_features = compounds[['NumC_A', 'NumN_A', 'NumO_A', 'NumF_A', 'NumCl_A','NumBr_A', 'NumB_A', 'NumSi_A', 'NumS_A', 'NumC_B', 'NumN_B', 'NumO_B','NumF_B', 'NumCl_B', 'NumBr_B', 'NumB_B', 'NumSi_B',"net", "linkerA_con", "linkerB_con"]]

# %%
composition_features2 = compounds[['NumC_A', 'NumN_A', 'NumO_A', 'NumF_A', 'NumCl_A','NumBr_A', 'NumB_A', 'NumSi_A', 'NumS_A', 'NumC_B', 'NumN_B', 'NumO_B','NumF_B', 'NumCl_B', 'NumBr_B', 'NumB_B', 'NumSi_B',"net", "linkerA_con", "linkerB_con","FractionCSP3_A","NumAliphaticCarbocycles_A","NumAliphaticHeterocycles_A","NumAliphaticRings_A","NumAromaticCarbocycles_A","NumAromaticHeterocycles_A","NumAromaticRings_A","NumHAcceptors_A","NumHDonors_A","NumHeteroatoms_A","NumRotatableBonds_A","NumSaturatedCarbocycles_A","NumSaturatedHeterocycles_A","NumSaturatedRings_A","RingCount_A","FractionCSP3_B","NumAliphaticCarbocycles_B","NumAliphaticHeterocycles_B","NumAliphaticRings_B","NumAromaticCarbocycles_B","NumAromaticHeterocycles_B","NumAromaticRings_B","NumHAcceptors_B","NumHDonors_B","NumHeteroatoms_B","NumRotatableBonds_B","NumSaturatedCarbocycles_B","NumSaturatedHeterocycles_B","NumSaturatedRings_B","RingCount_B"]]

# %%
composition_features.head()
# Out:
#    NumC_A  NumN_A  NumO_A  NumF_A  NumCl_A  NumBr_A  NumB_A  NumSi_A  NumS_A  \
# 0      12       0       2       0        0        4       0        0       0
# 1      12       0       2       0        0        4       0        0       0
# 2      12       0       2       0        0        4       0        0       0
# 3      12       0       2       0        0        4       0        0       0
# 4      12       0       2       0        0        4       0        0       0
#
#    NumC_B  NumN_B  NumO_B  NumF_B  NumCl_B  NumBr_B  NumB_B  NumSi_B  net  \
# 0      25       0       0       0        0        4       0        0  pts
# 1       6       2       4       0        0        2       0        0  qtz
# 2       6       2       4       0        0        2       0        0  und
# 3       6       4       0       0        0        2       0        0  unc
# 4       6       0       4       0        0        2       0        0  qtz
#
#   linkerA_con linkerB_con
# 0         CH2          NH
# ...

# %%
composition_features.to_csv("composition_features.csv", index = False)

# %%
composition_features2.to_csv("composition_features2.csv", index = False)

# %%
#compounds['C_fc'] = compounds.apply(lambda x: len(x["MoleculeA"].Formal(q)), axis=1)

# %%
# backup 

test = compounds.iloc[[0,1]]

test.head()

q = rdqueries.AtomNumEqualsQueryAtom(1)
len(test["MoleculeA"][0].GetAtomsMatchingQuery(q))

t = Lipinski.NumRotatableBonds(test["MoleculeA"][1])
print(t)
