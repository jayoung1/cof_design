# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn import metrics

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import normalize
from keras.layers.advanced_activations import LeakyReLU

# %%
composition = pd.read_csv('gdrive/My Drive/cofs/composition_features.csv')
structure = pd.read_csv('gdrive/My Drive/cofs/structural_features.csv')
properties = pd.read_csv('gdrive/My Drive/cofs/properties.csv')

# %%
properties = properties.drop("Unnamed: 0", axis = 1)
structure = structure.drop("Unnamed: 0", axis = 1)

# %%
properties.to_csv('gdrive/My Drive/cofs/properties.csv')

# %%
properties.head()
# Out:
#    absoluteMethaneUptakeHighP_mol_kg_  deliverableCapacity_vSTP_v_  \
# 0                           23.076498                   179.615836
# 1                           27.624233                   127.838063
# 2                           29.742485                   119.016669
# 3                           33.747905                   117.909108
# 4                           29.632996                   126.083029
#
#    heatDesorptionHighP_kJ_mol_  CO2Qst_kJ_mol_
# 0                     15.97766      -16.109667
# 1                      9.32583      -13.759106
# 2                      8.85691      -14.338564
# 3                      8.84098      -12.775519
# 4                      9.20892      -15.599998

# %%
composition.head()
# Out:
#    NumC_A  NumN_A  NumO_A  NumF_A  NumCl_A  NumBr_A  NumB_A  NumSi_A  NumS_A  \
# 0      12       0       2       0        0        4       0        0       0
# 1      12       0       2       0        0        4       0        0       0
# 2      12       0       2       0        0        4       0        0       0
# 3      12       0       2       0        0        4       0        0       0
# 4      12       0       2       0        0        4       0        0       0
#
#    NumC_B  NumN_B  NumO_B  NumF_B  NumCl_B  NumBr_B  NumB_B  NumSi_B  net  \
# 0      25       0       0       0        0        4       0        0  pts
# 1       6       2       4       0        0        2       0        0  qtz
# 2       6       2       4       0        0        2       0        0  und
# 3       6       4       0       0        0        2       0        0  unc
# 4       6       0       4       0        0        2       0        0  qtz
#
#   linkerA_con linkerB_con
# 0         CH2          NH
# 1         CH2          NH
# 2         CH2          NH
# 3         CH2          NH
# 4         CH2          NH

# %%
categorical = composition[["net", "linkerA_con", "linkerB_con"]]
composition = composition.drop(["net", "linkerA_con", "linkerB_con"], axis = 1)

ohe = OneHotEncoder()
encoded_columns = ohe.fit_transform(categorical)

df = pd.DataFrame(encoded_columns.toarray())

composition = pd.concat([composition, df], axis = 1)

# %%
composition.reset_index(drop=True, inplace=True)
structure.reset_index(drop=True, inplace=True)
combined_features = pd.concat([composition, structure], axis = 1)

# %%
combined_features.head()
# Out:
#    NumC_A  NumN_A  NumO_A  NumF_A  NumCl_A  NumBr_A  NumB_A  NumSi_A  NumS_A  \
# 0      12       0       2       0        0        4       0        0       0
# 1      12       0       2       0        0        4       0        0       0
# 2      12       0       2       0        0        4       0        0       0
# 3      12       0       2       0        0        4       0        0       0
# 4      12       0       2       0        0        4       0        0       0
#
#    NumC_B  ...  345  346  347  348  density_kg_m_3_  poreVolume_cm_3_g_  \
# 0      25  ...  0.0  0.0  0.0  1.0       428.773315             1.56524
# 1       6  ...  0.0  0.0  0.0  1.0       229.003535             3.70653
# 2       6  ...  0.0  0.0  0.0  1.0       198.302752             4.36176
# 3       6  ...  0.0  0.0  0.0  1.0       173.875856             5.03756
# 4       6  ...  0.0  0.0  0.0  1.0       209.972327             4.06587
#
#    largestIncludedSphereDiameter_A_  largestFreeSphereDiameter_A_  \
# 0                           8.95787                       7.53243
# 1                          16.67294                      15.77792
# 2                          21.06841                      18.89020
# 3                          23.03545                      22.69387
# 4                          17.44260                      16.02206
#
#    largestIncludedSphereAlongFreeSpherePathDiameter_A_  voidFraction_widom_
# 0                                            8.95787               0.771182
# 1                                           16.67294               0.883632
# 2                                           21.04678               0.902575
# 3                                           23.03545               0.906997
# 4                                           17.44259               0.889819
#
# [5 rows x 372 columns]

# %%
combined_features.to_csv("gdrive/My Drive/cofs/combined_features.csv")
