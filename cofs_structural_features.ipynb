# %%
import pandas as pd

# %%
df = pd.read_csv(r"../properties.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                    name  CO2KH_mol_kg_Pa_  \
# 0           0  linker100_CH2_linker103_NH_pts_relaxed          0.000019
# 1           1   linker100_CH2_linker10_NH_qtz_relaxed          0.000012
# 2           2   linker100_CH2_linker10_NH_und_relaxed          0.000013
# 3           3   linker100_CH2_linker11_NH_unc_relaxed          0.000012
# 4           4   linker100_CH2_linker12_NH_qtz_relaxed          0.000015
#
#    CO2Qst_kJ_mol_  surfaceArea_m_2_g__co2_properties_sorted  \
# 0      -16.109667                                   5573.98
# 1      -13.759106                                   6202.93
# 2      -14.338564                                   6342.94
# 3      -12.775519                                   7004.45
# 4      -15.599998                                   6619.28
#
#    poreVolume_cm_3_g_  frdens_kg_m_3_ linker_linkerBondType  dimensions  \
# 0             1.56524      428.773315                 amine           3
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'CO2KH_mol_kg_Pa_', 'CO2Qst_kJ_mol_',
#        'surfaceArea_m_2_g__co2_properties_sorted', 'poreVolume_cm_3_g_',
#        'frdens_kg_m_3_', 'linker_linkerBondType', 'dimensions', 'bondType',
#        'voidFraction_widom_', 'supercellVolume_A_3_', 'density_kg_m_3_',
#        'heatDesorptionHighP_kJ_mol_', 'absoluteMethaneUptakeHighP_mol_kg_',
#        'heatDesorptionLowP_kJ_mol_', 'absoluteMethaneUptakeLowP_mol_kg_',
#        'surfaceArea_m_2_g__ch4_properties_sorted',
#        'deliverableCapacity_vSTP_v_', 'linkerA', 'linkerB', 'net', 'cell_a_A_',
#        'cell_b_A_', 'cell_c_A_', 'alpha_deg_', 'beta_deg_', 'gamma_deg_',
#        'chemicalFormula', 'numCarbon', 'numFluorine', 'numHydrogen',
#        'numNitrogen', 'numOxygen', 'numSulfur', 'numSilicon', 'vertices',
#        'edges', 'genus', 'largestIncludedSphereDiameter_A_',
#        'largestFreeSphereDiameter_A_',
#        'largestIncludedSphereAlongFreeSpherePathDiameter_A_',
# ...

# %%
structural_features = df[['density_kg_m_3_', 'poreVolume_cm_3_g_','largestIncludedSphereDiameter_A_','largestFreeSphereDiameter_A_','largestIncludedSphereAlongFreeSpherePathDiameter_A_','voidFraction_widom_']]

# %%
structural_features.to_csv("structural_features.csv")
